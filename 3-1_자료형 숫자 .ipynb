# %% [markdown]
# ## 1. 숫자형은 어떻게 만들고 사용할까

# %% [markdown]
# 3. - 정수형,실수형 8진수 ,16진수 가능

# %% [markdown]
# a = 121

# %%
a
# Out:
# 121

# %%
a = 0o177
print(a)
# Out:
# 127

# %%
a= 0x8ff
b = 0xabc
print(a,b)
# Out:
# 2303 2748

# %% [markdown]
# # 2. 숫자형을 활용하기 위한 연산자

# %% [markdown]
# #### 사칙연산

# %%
>>> a = 3
>>> b = 5
a+b
# Out:
# 8

# %%
a-b
# Out:
# -2

# %%
a*b
# Out:
# 15

# %%
a/b
# Out:
# 0.6

# %% [markdown]
# ## 제곱 (**) 연산자

# %%
a**b
# Out:
# 243

# %% [markdown]
# ## 나머지(%)연산자

# %%
7%3
# Out:
# 1

# %% [markdown]
# ## 몫(//) 연산자

# %%
7//3
# Out:
# 2
