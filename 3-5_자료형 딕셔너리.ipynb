# %% [markdown]
# # 자료형 딕셔너리

# %% [markdown]
# ## 2.딕셔너리는 어떻게 만들까?

# %%
dic = {'name': '이재호', 'phone':'01045116346','birth':'1111'}
dic
# Out:
# {'name': '이재호', 'phone': '01045116346', 'birth': '1111'}

# %%
a = {1:'hi'}

# %%
a = {'a':[1,2,3]}

# %% [markdown]
# ## 3. 딕셔너리 쌍 추가,삭제하기

# %%
a = {1:'a'}
a[1] = 'x'
a
# Out:
# {1: 'x'}

# %%
a['jing'] = 'pey'
a
# Out:
# {1: 'x', 'jing': 'pey'}

# %%
del a[1]
a
# Out:
# {'jing': 'pey'}

# %% [markdown]
# ## 4.딕셔너리를 사용하는 방법

# %%
grade = {'pey': 10, 'julliet':99}
grade
# Out:
# {'pey': 10, 'julliet': 99}

# %%
a = {1:'a',2:'b'}
a[1]
# Out:
# 'a'

# %%
a[2]
# Out:
# 'b'

# %%
img = {'name':'pey','phone':'010-4511-6346','birth':'1118'}
img['name']
# Out:
# 'pey'

# %%
dic['phone']
# Out:
# '010-4511-6346'

# %%
dic['birth']
# Out:
# '1118'

# %%
keys = list(img.keys())
keys[0]
# Out:
# 'name'

# %%
keys[1]
# Out:
# 'phone'

# %%
a = {1:'a',1:'b'}
a
# Out:
# {1: 'b'}

# %% [markdown]
# ## 5. 딕셔너리 관련 함수

# %%
a = {'name':'pey','phone':'010-4511-6346','birth':'0502'}
a.values()
# Out:
# dict_values(['pey', '010-4511-6346', '0502'])

# %%
for k in a.keys():
    print(k)
# Out:
# name
# phone
# birth

# %%
a = {'name':'pey','phone':'010-4511-6346','birth':'0502'}
a.values()
# Out:
# dict_values(['pey', '010-4511-6346', '0502'])

# %%
for k in a.keys():
    print(k)
# Out:
# name
# phone
# birth

# %%
>>> a.values()

dict_values(['pey', '010-9999-1234', '1118'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 a.values()
# ----> 3 dict_values(['pey', '010-9999-1234', '1118'])
#
# NameError: name 'dict_values' is not defined

# %%
list(a.keys())
# Out:
# ['name', 'phone', 'birth']

# %%
 a.values()
# Out:
# dict_values(['pey', '010-4511-6346', '0502'])
