# %% [markdown]
# # 변수 -자료형의 값을 저장하는 공간

# %%
a = 1 #숫자형

# %%
b = "python" #문자열

# %%
c = [1,2,3] #리스트

# %%
id(c) #메모리 주소 확인
# Out:
# 1357958555968

# %%
c
# Out:
# [1, 2, 3]

# %%
id (a)
# Out:
# 140732556223400

# %% [markdown]
# ## 2.리스트를 복사 하자고 할 때

# %%
a = [1,2,3]
b = a
b
# Out:
# [1, 2, 3]

# %%
id(a)
# Out:
# 1357958552064

# %%
id(b)
# Out:
# 1357958552064

# %%
a is b #변수 a, 변수b는 같은 객체를 가르킴
# Out:
# True

# %%
# a에 있는 값 변경
a[0] = 4
a
# Out:
# [4, 2, 3]

# %%
b
# Out:
# [4, 2, 3]

# %%
b # a[0]변경했는데 b[0]도 변경됨
# Out:
# [4, 2, 3]

# %% [markdown]
# ### b변수에 a를 복사할 때 값만 복사하고 다른 주소를 가르키도록 만드는 방법.

# %%
a = [1,2,3]
b = a[:]
b
# Out:
# [1, 2, 3]

# %%
id(a)
# Out:
# 1357959093248

# %%
id (b)
# Out:
# 1357959096192

# %%
a[-1] = -3
a
# Out:
# [1, 2, -3]

# %%
b
# Out:
# [1, 2, 3]

# %% [markdown]
# - copy 모듈 이용하기

# %%
from copy improt copy
a = [1,2,3]
b = copy (a)
# Out:
#   Cell In[63], line 1
#     from copy improt copy
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# * copy() 함수 사용하기

# %%
a = [1,2,3]
b = a copy()
# Out:
#   Cell In[83], line 2
#     b = a copy()
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3.변수를 만드는 여러가지 방법

# %%
# 튜플로 변수 만들기
a,b = ('python', 'lfe')

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'lfe'

# %%
(a,b) = 'python','life'

# %%
print(a,b)
# Out:
# python life

# %%
a,b = 'python', 'life'

# %%
print(a,b)
# Out:
# python life

# %%
#리스트 변수 만들기
[a,b] = ['python', 'life']
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
# 여러 변수에 같은 값을 대입
a = b ='python'

# %%
print(a,b)
# Out:
# python python

# %%
id (a)
# Out:
# 1357804136768

# %%
id(b)
# Out:
# 1357804136768

# %%
# 두 변수의 값 바꾸기 (파이썬만 있는 기능)
a = 3
b = 5

# %%
a,b= b,a

# %%
print(a,b)
# Out:
# 5 3

# %%
a is b
# Out:
# False
