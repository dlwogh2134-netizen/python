# %% [markdown]
# # 리스트 자료형

# %% [markdown]
# ## 1. 리스트의 인덱싱과 슬라이싱

# %% [markdown]
# ### 리스트의 인덱싱

# %%
a = [1,2,3]
a
# Out:
# [1, 2, 3]

# %%
a[0]
# Out:
# 1

# %%
a[-1]
# Out:
# 3

# %%
a[0] + a[2]
# Out:
# 4

# %%
a = [1,2,3,['a','b','c',]]

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[3][1]
# Out:
# 'b'

# %%
a[3][0]
# Out:
# 'a'

# %%
a = [13,12,15]
a
# Out:
# [13, 12, 15]

# %%
a[0]
# Out:
# 13

# %%
a[0] + a[1]
# Out:
# 25

# %%
a[-2]
# Out:
# 12

# %%
a[-3]
# Out:
# 13

# %%
a = [1,2,3,['a','b','c']]

# %%
a
# Out:
# [1, 2, 3, ['a', 'b', 'c']]

# %%
a[0]
# Out:
# 1

# %%
a[-2]
# Out:
# 3

# %%
a[2]
# Out:
# 3

# %% [markdown]
# ### 삼중 리스트에서 인덱싱

# %%
a =[1,2, ['a','b',['Life','is']]]

# %%
a[2]
# Out:
# ['a', 'b', ['Life', 'is']]

# %%
a[2][2]
# Out:
# ['Life', 'is']

# %%
a[2][2][0]
# Out:
# 'Life'

# %%
a = [1,2,3,4,5]
a[2:4]
# Out:
# [3, 4]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[3:]
# Out:
# [4, 5]

# %%
a = [a,b,['1','2',['Life','is']]]
a
# Out:
# [[1, 2, 3, ['a', 'b', 'c']], [4, 5, 6], ['1', '2', ['Life', 'is']]]

# %%
a[2][2]
# Out:
# ['Life', 'is']

# %% [markdown]
# ### 중첩된 리스트에서 슬라이싱하기

# %%
a = [1,2,3,['a','b','c',],4,5]

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[2:5]
# Out:
# [3, ['a', 'b', 'c'], 4]

# %%
a[3][:2]
# Out:
# ['a', 'b']

# %% [markdown]
# ## 2.리스트 연산하기

# %%
# 리스트 더하기
a = [1,2,3]
b = [4,5,6]
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a*1
# Out:
# [1, 2, 3]

# %%
len(a)
# Out:
# 3

# %%
a[2] + 'hi'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a[2] + 'hi'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a[2])
# Out:
# '3'

# %%
str(a[2])+ 'hi'
# Out:
# '3hi'

# %%
a + list ('hi')
# Out:
# [1, 2, 3, 'h', 'i']

# %%
list ('hi')
# Out:
# ['h', 'i']

# %% [markdown]
# ## 3.리스트의 수정과 삭제

# %%
a = [1,2,3]
a[2] = 4

# %%
a
# Out:
# [1, 2, 4]

# %%
del a[1]

# %%
a
# Out:
# [1, 4]

# %%
a = [1,2,3,4,5]
del a[2:]

# %%
a
# Out:
# [1, 2]

# %% [markdown]
# ## 4.리스트 관련 함수

# %% [markdown]
# ### append(value): 리스트에 요소 추가하기_

# %%
a = [1,2,3]
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a.append([5,6])

# %%
a
# Out:
# [1, 2, 3, 4, [5, 6]]

# %%
a = [1,2,3]
a+ [5,6]
# Out:
# [1, 2, 3, 5, 6]

# %%
a = a+ [5,6]
a
# Out:
# [1, 2, 3, 5, 6]

# %% [markdown]
# sort():리스트 정렬

# %%
a = [4,1,3,2]
a.sort()

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a = [a,c,d,b]
a.sort()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 a = [a,c,d,b]
#       2 a.sort()
#
# NameError: name 'c' is not defined

# %% [markdown]
#  ### reverse() 리스트 뒤집기

# %%
a = ['c','a','b']
a.reverse()

# %%
a
# Out:
# ['b', 'a', 'c']

# %% [markdown]
# ### index():인덱스 변환

# %%
a = [1,2,3,4,5]
a.index(3)
# Out:
# 2

# %%
a[2]
# Out:
# 3

# %% [markdown]
# ### insert(index.value):리스트에 요소 삽입

# %%
a = [1,2,3]
a.insert(0,4)

# %%
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3,5)
a
# Out:
# [4, 1, 2, 5, 3]

# %% [markdown]
# ### remove(value):리스트 요소 제거

# %%
a = [1,2,3,1,2,3]
a.remove(3)

# %%
a
# Out:
# [1, 2, 1, 2, 3]

# %% [markdown]
# ### pop(): 리스트요소 끄집어 내기

# %%
a.pop() #원본 데이터 변경됨
# Out:
# 3

# %%
a
# Out:
# [1, 2, 1, 2]

# %%
a.pop(1)
# Out:
# 2

# %%
a
# Out:
# [1, 1, 2]

# %% [markdown]
# ### count(value):리스트에 포함되누 요소의 값으로 개수 세기

# %%
a = [1,2,3,1,2,3]
a.count(3)
# Out:
# 2

# %% [markdown]
# ### extend(value):리스트 확장

# %%
a = [1,2,3]
a.extend([4,5])

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.extend(['a','b'])
a
# Out:
# [1, 2, 3, 4, 5, [...], [4, 5, 6], [...], [4, 5, 6], 'a', 'b', 'a', 'b']

# %%
a
# Out:
# [1, 2, 3, 4, 5, [...], [4, 5, 6], [...], [4, 5, 6], 'a', 'b', 'a', 'b']
