# %% [markdown]
# ## 4.문자형 자료형

# %% [markdown]
# ## 1. 문자열은 어떻게 만들고 사용할까?
# - 큰 따옴표: ""
# - 작은 따옴표:''
# - 큰 따옴표 3개: """ """
# - 작은 따옴표 3개: ''' '''

# %% [markdown]
# ### 2. 문자열 안에 작은 따옴표나 큰따옴표를 문자로 포함시키고 싶을 때

# %%
food = "python's favorie food is perl"
food
# Out:
# "python's favorie food is perl"

# %%
food = '\python\'s favorite is perl'

# %%
say = "\"안녕하세요\"라고 말했습니다."

# %%
food = 'python\'s favorite is perl'

# %%
say = "\"안녕하세요\"라고 말했습니다."

# %% [markdown]
# ### 3. 여러 줄의 문자열을 변수에 대입하고 싶을때

# %% [markdown]
# ### 이스케이프 코드 \ n삽입

# %%
multiline = "life si too short.\nyou need python"
multiline
# Out:
# 'life si too short.\nyou need python'

# %% [markdown]
# multiline = "life si too short.\nyou need python"
# print(multiline)

# %% [markdown]
# ## 4.문자열 연산하기

# %%
head = "python"
tail = "is fun!"
head + tail
# Out:
# 'pythonis fun!'

# %%
a = "python"
a*2
# Out:
# 'pythonpython'

# %%
print ('='*50)
print ("my program")
print ('='*50)
# Out:
# ...
# my program
# ...

# %% [markdown]
# ## 5. 문자열 길이 구하기

# %%
a = 'life is too short'
len(a)
# Out:
# 17

# %%
len ('life is too short')
# Out:
# 17

# %% [markdown]
# ## 6. 문자열 인덱싱과 슬라이싱

# %%
a = "life is too short, you need python"

# %%
len(a)
# Out:
# 34

# %%
a[3]
# Out:
# 'e'

# %%
a[-6]
# Out:
# 'p'

# %%
a[17]
# Out:
# ','

# %%
a[28]
# Out:
# 'p'

# %%
a = "life is too short, you need pyhton"
a[0:4]
'life'
# Out:
# 'life'

# %%
a[0:2]
# Out:
# 'li'

# %%
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'life'

# %%
a[0:4]
# Out:
# 'life'

# %%
a[5:7]
# Out:
# 'is'

# %%
a[3:28]
# Out:
# 'e is too short, you need '

# %%
# short 문자만 잘라내기
a[12:17
# Out:
# 'short'

# %%
a[22:27]
# Out:
# ' need'

# %%
a[19:22]
# Out:
# 'you'

# %%
a[28:34]
# Out:
# 'pyhton'

# %%
a
# Out:
# 'life is too short, you need pyhton'

# %%
a[:17]
# Out:
# 'life is too short'

# %%
a = "20260225sunny"

# %%
a[1:8]
# Out:
# '0260225'

# %%
a[1:
# Out:
# '0260225sunny'

# %%
a[0:8]
# Out:
# '20260225'

# %%
a[8:14]
# Out:
# 'sunny'

# %%
a[0:4]
# Out:
# '2026'

# %%
a[4:6]
# Out:
# '02'

# %%
a[6:8]
# Out:
# '25'

# %% [markdown]
# ### pithon 문자열을 python 바꾸려면?

# %%
a = 'pithon'
a
# Out:
# 'pithon'

# %%
a[1] = 'y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a[1] = 'y'
#
# TypeError: 'str' object does not support item assignment

# %%
b = a[0] + 'y' + a[2:]
b
# Out:
# 'python'

# %%
print (a, d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print (a, d)
#
# NameError: name 'd' is not defined

# %%
a = 'python'

# %%
a
# Out:
# 'python'

# %% [markdown]
# ## 7. 문자열 포매팅

# %%
#  1) 숫자 바로 대입
food = "I eat %d apples." %5
food
# Out:
# 'I eat 5 apples.'

# %%
# 2) 문자열 바로 대입
food = "I eat %s apples." % 'there'
food
# Out:
# 'I eat there apples.'

# %%
# 3) 숫자 값을 나타내는 변수로 대입
number = 3
food = "I eat %d apples." %number
food
# Out:
# 'I eat 3 apples.'

# %%
# 4) 2개 이상의 갑 넣기
num = 10
day = 'theree'

'I eat %d apples. so I was sick for %s days' %(num, day)
# Out:
# 'I eat 10 apples. so I was sick for theree days'

# %%
# #s는 숫자도 문자열로 대입 가능
'i have %s apples.'%3
# Out:
# 'i have 3 apples.'

# %%
'I have %d apples.' %3.14
# Out:
# 'I have 3 apples.'

# %%
'I have %f apples.' %3.14
# Out:
# 'I have 3.140000 apples.'

# %%
'I have %s apples.' %3.14
# Out:
# 'I have 3.14 apples.'

# %%
# 포멧 코드와 문자 %를 같이 사용하려면 %%
'Error is %d%%.' %98
# Out:
# 'Error is 98%.'

# %% [markdown]
# ### 포멧 코드와 숫자 함께 사용하기

# %%
# 1) 정렬과 공백
'%s' %'hi'
# Out:
# 'hi'

# %%
a = '%10s' %'hi'
a
# Out:
# '        hi'

# %%
a[0]
# Out:
# ' '

# %%
a[8]
# Out:
# 'h'

# %%
a[-1]
# Out:
# 'i'

# %%
'%-10s' %'hi'
# Out:
# 'hi        '

# %%
# 2) 소수점 표현하기
'%f' %3.42134234
# Out:
# '3.421342'

# %%
'%0.4f' %
# Out:
# '3.4213'

# %%
'%0.2f' %3.42134234
# Out:
# '3.42'

# %%
a = '%10.4f' %3.42134234
a
# Out:
# '    3.4213'

# %% [markdown]
# ## 10format () 함수를 사용한 포매팅

# %%
# 숫자 바로 대입
'I eat {}apples'. format(3)
# Out:
# 'I eat 3apples'

# %%
# 문자 바로 대입
'I eat {} apples'. format ('three')
# Out:
# 'I eat three apples'

# %%
# 변수로 대입
num = 3

# %%
# 2개 이상 넣기
num = 10
day = 'three'

# %%
'I ate {} apples. so I was sick for {} days'.format(num, day)
# Out:
# 'I ate 10 apples. so I was sick for three days'

# %%
'I ate {0} apples. so I was sick for {1} days'.format(num, day)
# Out:
# 'I ate 10 apples. so I was sick for three days'

# %%
'I ate {1} apples. so I was sick for {0} days'.format(num, day)
# Out:
# 'I ate three apples. so I was sick for 10 days'

# %%
# 이름으로 넣기
'I ate {number} apples. so I was sick for {day} days'.format(day=3, number=10)
# Out:
# 'I ate 10 apples. so I was sick for 3 days'

# %%
'I ate {} apples. so I was for {day} days.'.format(10, day=3)
# Out:
# 'I ate 10 apples. so I was for 3 days.'

# %%
# 왼쪽 정렬
'{}'.format('hi')
# Out:
# 'hi'

# %%
'{:<10}'.format('hi')
# Out:
# 'hi        '

# %%
'{:>10}'.format ('hi')
# Out:
# '        hi'

# %%
'{:^10}'.format('hi')
# Out:
# '    hi    '

# %%
# 공백 채우기
'{=^10}'.format('hi')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 2
#       1 # 공백 채우기
# ----> 2 '{=^10}'.format('hi')
#
# KeyError: '=^10'

# %%
'{!<10}'.format('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 '{!<10}'.format('hi')
#
# ValueError: expected ':' after conversion specifier

# %%
#소수점 표현
'{:0.2f}'.format(3.141592)
# Out:
# '3.14'

# %%
'{:10.2f}'.format(3.141592)
# Out:
# '      3.14'

# %%
'{{and}}'.format()
# Out:
# '{and}'

# %%
'{}'.format('{and}')
# Out:
# '{and}'

# %% [markdown]
# ## 11.f문자열 포매팅

# %%
# 문자열 앞에 f 접두사를 붙이기
name = '이재호'
age = 20
f'나의 이름은 {anme}입니다. 나이는 {age}입니다.'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 4
#       2 name = '이재호'
#       3 age = 20
# ----> 4 f'나의 이름은 {anme}입니다. 나이는 {age}입니다.'
#
# NameError: name 'anme' is not defined

# %%
#표현식 사용하기 
f'나는 내년이면 21살이 됩니다'
# Out:
# '나는 내년이면 21살이 됩니다'

# %%
d = {'name': '이재호', 'age' : 20}
f'나의 이름은 {d['name']}입니다. 나이는 (d['age'])입니다.'
# Out:
#   Cell In[103], line 2
#     f'나의 이름은 {d['name']}입니다. 나이는 (d['age'])입니다.'
#                                      ^
# SyntaxError: invalid syntax

# %%
# 정렬
f'{'hi':<10}'
# Out:
# 'hi        '

# %%
f'{'hi':>10}'
# Out:
# '        hi'

# %%
f'{'hi':^10}'
# Out:
# '    hi    '

# %%
f'{'hi':=^10}'
# Out:
# '====hi===='

# %%
f'{'hi':!<10}'
# Out:
# 'hi!!!!!!!!'

# %%
# 소수점 표현
f'{3.141592:0.2f}'
# Out:
# '3.14'

# %%
f'{3.141592:10.2f}'
# Out:
# '      3.14'

# %%
f'{3.141592:100.2f}'
# Out:
# '                                                                                                3.14'

# %%
f'{3.141592:<10.2f}'
# Out:
# '3.14      '

# %%
f'{3.141592:-10.2f}'
# Out:
# '      3.14'

# %%
f'{3.141592:0<10.2f}'
# Out:
# '3.14000000'

# %%
f'{{and}}'
# Out:
# '{and}'

# %% [markdown]
# ## 12.문자열 관련 함수들

# %% [markdown]
# ### count()

# %%
a = 'hobby'
a.count('b')
# Out:
# 2

# %% [markdown]
# ### fint()

# %%
a = 'Python is the best choice'
a.find('b')
# Out:
# 14

# %%
a.find('P')
# Out:
# 0

# %%
a.find('k')
# Out:
# -1

# %%
a.find('kg')
# Out:
# -1

# %% [markdown]
# ### index()

# %%
a.index ('b')
# Out:
# 14

# %%
a.index ('k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 a.index ('k')
#
# ValueError: substring not found

# %% [markdown]
# ### join()

# %%
', '.join('abcd')
# Out:
# 'a, b, c, d'

# %%
list = ', '.join('a','b','c','d',)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 list = ', '.join('a','b','c','d',)
#
# TypeError: str.join() takes exactly one argument (4 given)

# %%
' , '.join(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 ' , '.join(list)
#
# TypeError: can only join an iterable

# %% [markdown]
# ### upper(): 소문자를 대문자로

# %%
a = 'hi'
a.upper()
# Out:
# 'HI'

# %% [markdown]
# ### lower() 대문자를 소문자로

# %%
a = 'HI'
a.lower()
# Out:
# 'hi'

# %% [markdown]
# ### lstrip(): 왼쪽 공백 지우기

# %%
a ='    hi      '
a.lstrip()
# Out:
# 'hi      '

# %% [markdown]
# ### rstrip(): 오른쪽 공백 지우기

# %%
a ='          hi            '
a.rstrip()
# Out:
# '          hi'

# %% [markdown]
# ### strip(): 양쪽 공백 지우기

# %%
a ='            hi                       '
a.strip()
# Out:
# 'hi'

# %% [markdown]
# ### replace(): 문자열 바꾸기

# %%
a = 'life is too short.'
a.replace('life','your leg')
# Out:
# 'your leg is too short.'

# %%
a
# Out:
# 'life is too short.'

# %%
a = a.replace('Life','your leg')

# %%
a
# Out:
# 'life is too short.'

# %% [markdown]
# ### split(): 문자열 나누기

# %%
a = 'Life is too short'
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
a
# Out:
# 'Life is too short'

# %%
type(a)
# Out:
# str

# %%
type(a.split())
# Out:
# list

# %%
b = 'a,b,c,d'
b.split(',')
# Out:
# ['a', 'b', 'c', 'd']

# %%
b = 'a;b;c;d'
b.split(';')
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### 착각하기 쉬운 문자열 함수

# %%
a= 'hi'
a.upper()
# Out:
# 'HI'

# %%
a
# Out:
# 'hi'
