# %% [markdown]
# # 제어문 / 조건문(if문)

# %%
money = True

if money:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
money = False

if money:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %%
# 들여쓰기 잘못한 경우
money = True

if money:
    print('택시를 ')
    print('타고 ')
    print('가라 ')
# Out:
# 택시를
# 타고
# 가라

# %%
# 들여쓰기 잘못한 경우
money = True

if money:
      print('택시를 ')
      print('타고 ')
         print('가라 ')
# Out:
#   Cell In[22], line 7
#     print('가라 ')
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 2.연산자

# %%
# 비고 연산자 = bool반환
x = 3
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
money = 2000

if money >= 3000:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %%
money = 3001

if money >= 3000:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
# 논리 연산자
money = 2000
card = True

if money >= 3000 or card:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
money = 2000
card = False

if money >= 3000 or card:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %%
# in 연산자
1 in [1,2,3]
# Out:
# True

# %%
4 in [1,2,3]
# Out:
# False

# %%
1 not in [1,2,3]
# Out:
# False

# %%
4 not in [1,2,3]
# Out:
# True

# %%
'a' in ('a','b','c')
# Out:
# True

# %%
't' in 'python'
# Out:
# True

# %%
'i' in 'python'
# Out:
# False

# %%
'i' not in 'python'
# Out:
# True

# %%
pocket = ['prpar', 'cellphone', 'money']

if 'money' in pocket:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
if 'card' in pocket:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 걸어가라

# %%
# 주머니에 돈이 있으면 가만히 있고,
#주머니에 카드가 없으면 카드를 꺼내라
pocket = ['prpar', 'cellphone', 'money']

if 'money' in pocket:
    pass
else:
    print ('카드를 꺼내라')

# %%
pocket = ['prpar', 'cellphone', 'money']
if 'money' in pocket:
    pass
else:
    print ('카드를 꺼내라')

# %% [markdown]
# ## 3. 다양한 조건을 판단하는 elif

# %%
# if/else로만 표현

# %%
pocket = ['prpar', 'cellphone', 'money']
card = True

if 'money' in pocket:
    print('택시를 타고 가라')
else:
    if card:
        print('택시를 타고 가라')
    else:
        print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
# elif를 사용
if 'money' in pocket:
    print('택시를 타고 가라')
elif card:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
# if 문 한 줄로 작성
if 'money' in pocket : pass
else: print('카드를 꺼내라')

# %% [markdown]
# ## 4. 조건부 표현식

# %%
# if문
score = 30


if score >=60:
    message = 'succes'
else:
    message = 'failure'

print (message)
# Out:
# failure

# %%
# 조건부 표현식 (conditional expressing)
score = 90
message = 'success' if score >=60 else "failure"
message
# Out:
# 'success'
